# %%
import pandas as pd

# %%
# Vamos leeiendo los varios archivos csv
df_listing = pd.read_csv('data/listings.csv')
df_reviews = pd.read_csv('data/reviews.csv')
df_barrios = pd.read_csv('data/neighbourhoods.csv')

# %%
# mostramos información de los dataframes
df_listing.info()
df_reviews.info()
df_barrios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19482 entries, 0 to 19481
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19482 non-null  int64
#  1   name                            19482 non-null  object
#  2   host_id                         19482 non-null  int64
#  3   host_name                       19480 non-null  object
#  4   neighbourhood_group             19482 non-null  object
#  5   neighbourhood                   19482 non-null  object
#  6   latitude                        19482 non-null  float64
#  7   longitude                       19482 non-null  float64
#  8   room_type                       19482 non-null  object
#  9   price                           15422 non-null  float64
#  10  minimum_nights                  19482 non-null  int64
#  11  number_of_reviews               19482 non-null  int64
# ...

# %%
df_reviews2 = pd.read_csv('data/reviews_2.csv')
df_listing2 = pd.read_csv('data/listings_2.csv')
df_calendar = pd.read_csv('data/calendar.csv', low_memory=False)

# %%
df_reviews2.info()
df_listing2.info()
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927474 entries, 0 to 927473
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     927474 non-null  int64
#  1   id             927474 non-null  int64
#  2   date           927474 non-null  object
#  3   reviewer_id    927474 non-null  int64
#  4   reviewer_name  927474 non-null  object
#  5   comments       927382 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 42.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19482 entries, 0 to 19481
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            19482 non-null  int64
#  1   listing_url                                   19482 non-null  object
# ...

# %%
# mostramos todas las columnas de los vartios dataframes
print(df_listing.columns)
def mostrar_columnas(df):
    print(df.columns)

# mostramos todas las columnas de los varios dataframes
mostrar_columnas(df_listing)
mostrar_columnas(df_reviews)
mostrar_columnas(df_barrios)
mostrar_columnas(df_reviews2)
mostrar_columnas(df_listing2)
mostrar_columnas(df_calendar)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')
# Index(['listing_id', 'date'], dtype='object')
# Index(['neighbourhood_group', 'neighbourhood'], dtype='object')
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')
# ...

# %%
# mostramos el contenido del df_calendar
df_calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0      331026  2024-09-07         f  $40.00            NaN             3.0
# 1      331026  2024-09-08         f  $40.00            NaN             3.0
# 2      331026  2024-09-09         f  $40.00            NaN             3.0
# 3      331026  2024-09-10         f  $40.00            NaN             3.0
# 4      331026  2024-09-11         f  $40.00            NaN             3.0
#
#    maximum_nights
# 0             6.0
# 1             6.0
# 2             6.0
# 3             6.0
# 4             6.0

# %%
# mostrramos para el df_calendar el valor unico de linsting_id vemos cuantas veces se repite el valor
print(df_calendar['listing_id'].value_counts())
# Out:
# listing_id
# 1157789657547374208    366
# 855084253369890996     366
# 53536192               366
# 18703222               366
# 636702                 365
#                       ...
# 645513                 365
# 343866                 365
# 40983                  365
# 648112                 365
# 335861                 365
# Name: count, Length: 19482, dtype: int64

# %%
df_calendar.describe().T
# Out:
#                     count          mean           std      min         25%  \
# listing_id      7110934.0  4.645671e+17  4.960977e+17  18674.0  25408427.0
# minimum_nights  7110931.0  1.752073e+01  3.702600e+01      1.0         2.0
# maximum_nights  7110931.0  2.210486e+05  2.175733e+07      1.0       330.0
#
#                        50%           75%           max
# listing_id      53397556.0  9.651084e+17  1.239619e+18
# minimum_nights         4.0  3.100000e+01  1.124000e+03
# maximum_nights       365.0  1.125000e+03  2.147484e+09

# %%
df_calendar.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'listing_id'}>,
#         <Axes: title={'center': 'minimum_nights'}>],
#        [<Axes: title={'center': 'maximum_nights'}>, <Axes: >]],
#       dtype=object)

# %%
df_calendar.isnull().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price                   0
# adjusted_price    7110204
# minimum_nights          3
# maximum_nights          3
# dtype: int64

# %%
df_calendar.shape
# Out:
# (7110934, 7)

# %%
# Voya mirar los datos esenciales del df_listing
df_listing.describe().T
# Out:
#                                   count          mean           std  \
# id                              19482.0  4.645671e+17  4.961103e+17
# host_id                         19482.0  1.902875e+08  1.924666e+08
# latitude                        19482.0  4.139218e+01  1.415366e-02
# longitude                       19482.0  2.167016e+00  1.769744e-02
# price                           15422.0  1.686336e+02  2.626864e+02
# minimum_nights                  19482.0  1.539380e+01  3.078637e+01
# number_of_reviews               19482.0  4.760671e+01  9.935046e+01
# reviews_per_month               14731.0  1.518737e+00  2.074713e+00
# calculated_host_listings_count  19482.0  4.136824e+01  8.845460e+01
# availability_365                19482.0  1.772067e+02  1.253229e+02
# number_of_reviews_ltm           19482.0  1.190581e+01  2.481316e+01
#
#                                          min           25%           50%  \
# id                              18674.000000  2.541083e+07  5.339735e+07
# ...

# %%
df_listing.head()
# Out:
#       id                                               name  host_id  \
# 0  18674    Huge flat for 8 people close to Sagrada Familia    71615
# 1  23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax    90417
# 2  32711                   Sagrada Familia area - Còrsega 1   135703
# 3  34241   Stylish Top Floor Apartment - Ramblas Plaza Real    73163
# 4  34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS    73163
#
#         host_name neighbourhood_group                       neighbourhood  \
# 0   Mireia  Maria            Eixample                  la Sagrada Família
# 1  Etain (Marnie)          Sant Martí               el Besòs i el Maresme
# 2            Nick              Gràcia  el Camp d'en Grassot i Gràcia Nova
# 3          Andres        Ciutat Vella                      el Barri Gòtic
# 4          Andres        Ciutat Vella                      el Barri Gòtic
#
#     latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
df_listing.hist(figsize=(10,10))
df_listing.shape
# Out:
# (19482, 18)

# %%
df_listing['room_type'].unique()
df_listing['room_type'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# room_type
# Entire home/apt    11589
# Private room        7615
# Shared room          160
# Hotel room           118
# Name: count, dtype: int64

# %%
df_listing['license'].value_counts(dropna=False)
# Out:
# license
# NaN            6194
# Exempt         5321
# HUTB-000000     136
# HUTB-123456      27
# AJ000593         22
#                ...
# HUTB000329        1
# HUTb-005204       1
# HUTB-012603       1
# HUTB-000328       1
# HUTB-836295       1
# Name: count, Length: 6036, dtype: int64

# %%
df_reviews.describe().T
# Out:
#                count          mean           std      min        25%  \
# listing_id  927474.0  1.108318e+17  2.886056e+17  18674.0  3389920.0
#
#                    50%         75%           max
# listing_id  18072457.0  41399566.0  1.227948e+18

# %%
df_reviews.head()
# Out:
#    listing_id        date
# 0      252232  2012-03-02
# 1      252232  2012-05-22
# 2      252232  2012-06-11
# 3      252232  2012-07-28
# 4      252232  2012-09-02

# %%
df_reviews.hist(figsize=(5,5))
df_reviews.shape
# Out:
# (927474, 2)

# %%
df_reviews['listing_id'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# listing_id
# 52981104               2453
# 35118964               2132
# 24424717               1326
# 30760852               1323
# 51201977               1254
#                        ...
# 1203538650184201592       1
# 1203410522957588807       1
# 1203388205050933268       1
# 38869936                  1
# 39150196                  1
# Name: count, Length: 14731, dtype: int64

# %%
df_reviews.groupby('listing_id')['date'].nunique()
# Out:
# listing_id
# 18674                   42
# 23197                   79
# 32711                  128
# 34241                   20
# 34981                  247
#                       ...
# 1223841447226445161      1
# 1225540221775878403      1
# 1226639678203846655      1
# 1226644265166272585      2
# 1227947729562300326      2
# Name: date, Length: 14731, dtype: int64

# %%
df_barrios.describe().T
# Out:
#                     count unique             top freq
# neighbourhood_group    73     10      Nou Barris   13
# neighbourhood          73     73  el Barri Gòtic    1

# %%
df_barrios.head()
# Out:
#   neighbourhood_group                          neighbourhood
# 0        Ciutat Vella                         el Barri Gòtic
# 1        Ciutat Vella                               el Raval
# 2        Ciutat Vella                         la Barceloneta
# 3        Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 4            Eixample                          el Fort Pienc

# %%
df_barrios['neighbourhood_group'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# neighbourhood_group
# Nou Barris             13
# Horta-Guinardó         11
# Sant Martí             10
# Sants-Montjuïc          8
# Sant Andreu             7
# Eixample                6
# Sarrià-Sant Gervasi     6
# Gràcia                  5
# Ciutat Vella            4
# Les Corts               3
# Name: count, dtype: int64

# %%
df_barrios['neighbourhood'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# neighbourhood
# el Barri Gòtic                           1
# el Raval                                 1
# la Barceloneta                           1
# Sant Pere, Santa Caterina i la Ribera    1
# el Fort Pienc                            1
#                                         ..
# les Tres Torres                          1
# Sant Gervasi - Galvany                   1
# Sant Gervasi - la Bonanova               1
# Sarrià                                   1
# Vallvidrera, el Tibidabo i les Planes    1
# Name: count, Length: 73, dtype: int64

# %%
df_barrios.groupby('neighbourhood_group')['neighbourhood'].nunique()
# Out:
# neighbourhood_group
# Ciutat Vella            4
# Eixample                6
# Gràcia                  5
# Horta-Guinardó         11
# Les Corts               3
# Nou Barris             13
# Sant Andreu             7
# Sant Martí             10
# Sants-Montjuïc          8
# Sarrià-Sant Gervasi     6
# Name: neighbourhood, dtype: int64

# %%
df_reviews2.describe().T
# Out:
#                 count          mean           std      min           25%  \
# listing_id   927474.0  1.108318e+17  2.886056e+17  18674.0  3.389920e+06
# id           927474.0  5.397149e+17  4.693573e+17  63148.0  4.168468e+08
# reviewer_id  927474.0  1.623857e+08  1.596583e+08      3.0  3.335601e+07
#
#                       50%           75%           max
# listing_id   1.807246e+07  4.139957e+07  1.227948e+18
# id           6.360384e+17  9.752002e+17  1.239819e+18
# reviewer_id  1.031359e+08  2.468413e+08  5.996828e+08

# %%
df_reviews2.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0       18674    4808211  2013-05-27      4841196         Caron
# 1       18674   10660311  2014-03-02     11600277   Juan Carlos
# 2       18674   41087522  2015-08-04     35231385        Shlomi
# 3       18674   81000756  2016-06-20     23223644         Joost
# 4       18674  278588962  2018-06-18      4756672        Marius
#
#                                             comments
# 0  Great location. Clean, spacious flat. Would re...
# 1  Mi mejor recomendación para este departamento....
# 2  Big apartment, well equipped.\r<br/>Very good ...
# 3  The Check in was fast and flexible. The price ...
# 4  Great location and enough space in the apartme...

# %%
df_reviews2.hist(figsize=(10,10))
df_reviews2.shape
# Out:
# (927474, 6)

# %%
df_reviews2.groupby('listing_id')['reviewer_id'].nunique()
# Out:
# listing_id
# 18674                   42
# 23197                   79
# 32711                  128
# 34241                   20
# 34981                  247
#                       ...
# 1223841447226445161      1
# 1225540221775878403      1
# 1226639678203846655      1
# 1226644265166272585      2
# 1227947729562300326      2
# Name: reviewer_id, Length: 14731, dtype: int64

# %%
df_reviews2['listing_id'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# listing_id
# 52981104               2453
# 35118964               2132
# 24424717               1326
# 30760852               1323
# 51201977               1254
#                        ...
# 1208579788830266767       1
# 1209137739796822063       1
# 1209187965448897250       1
# 1207042820995281434       1
# 1222251302426222162       1
# Name: count, Length: 14731, dtype: int64

# %%
df_listing2.describe().T
# Out:
#                                                 count          mean  \
# id                                            19482.0  4.645671e+17
# scrape_id                                     19482.0  2.024091e+13
# host_id                                       19482.0  1.902875e+08
# host_listings_count                           19480.0  5.676042e+01
# host_total_listings_count                     19480.0  7.229245e+01
# latitude                                      19482.0  4.139218e+01
# longitude                                     19482.0  2.167016e+00
# accommodates                                  19482.0  3.335130e+00
# bathrooms                                     15425.0  1.401912e+00
# bedrooms                                      17428.0  1.796075e+00
# beds                                          15336.0  2.431403e+00
# minimum_nights                                19482.0  1.539380e+01
# maximum_nights                                19482.0  5.315827e+02
# ...

# %%
df_listing2.head()
pd.set_option('display.max_columns', None)
df_listing2.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  18674  https://www.airbnb.com/rooms/18674  20240906140800   2024-09-06
# 1  23197  https://www.airbnb.com/rooms/23197  20240906140800   2024-09-06
# 2  32711  https://www.airbnb.com/rooms/32711  20240906140800   2024-09-06
# 3  34241  https://www.airbnb.com/rooms/34241  20240906140800   2024-09-06
# 4  34981  https://www.airbnb.com/rooms/34981  20240906140800   2024-09-06
#
#         source                                               name  \
# 0  city scrape    Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2  city scrape                   Sagrada Familia area - Còrsega 1
# 3  city scrape   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4  city scrape               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# ...

# %%
df_listing2.hist(figsize=(20,20))
df_listing2.shape
# Out:
# (19482, 75)

# %%
df_listing2['source'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# source
# city scrape        15432
# previous scrape     4050
# Name: count, dtype: int64

# %%
df_listing2['host_response_time'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# host_response_time
# within an hour        11662
# NaN                    3047
# within a few hours     2995
# within a day           1195
# a few days or more      583
# Name: count, dtype: int64

# %%
df_listing2['host_is_superhost'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# host_is_superhost
# f      15198
# t       3863
# NaN      421
# Name: count, dtype: int64

# %%
df_listing2['host_neighbourhood'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# host_neighbourhood
# NaN                    9772
# Dreta de l'Eixample    1660
# Vila de Gràcia          826
# El Poble-sec            643
# El Raval                630
#                        ...
# Boa Viagem                1
# Mijas Costa               1
# Diagonal Mar              1
# Mile End                  1
# LB of Hackney             1
# Name: count, Length: 147, dtype: int64

# %%
df_listing2['host_verifications'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# host_verifications
# ['email', 'phone']                  14979
# ['email', 'phone', 'work_email']     2401
# ['phone']                            1248
# ['phone', 'work_email']               808
# ['email']                              35
# []                                      7
# NaN                                     2
# ['email', 'work_email']                 1
# ['work_email']                          1
# Name: count, dtype: int64

# %%
df_listing2['neighbourhood_cleansed'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# neighbourhood_cleansed
# la Dreta de l'Eixample                   2359
# el Raval                                 1566
# el Barri Gòtic                           1265
# Sant Pere, Santa Caterina i la Ribera    1219
# la Sagrada Família                       1136
#                                          ...
# la Clota                                    5
# Baró de Viver                               3
# Torre Baró                                  2
# Can Peguera                                 2
# Canyelles                                   2
# Name: count, Length: 71, dtype: int64

# %%
df_listing2['property_type'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# property_type
# Entire rental unit                    10204
# Private room in rental unit            6052
# Entire serviced apartment               455
# Room in hotel                           426
# Entire condo                            405
# Entire loft                             292
# Private room in condo                   233
# Private room in hostel                  206
# Room in boutique hotel                  192
# Private room in home                    192
# Private room in bed and breakfast       108
# Entire home                             101
# Shared room in hostel                    96
# Private room in casa particular          65
# Private room in serviced apartment       44
# Private room in guest suite              42
# Shared room in rental unit               36
# Private room in loft                     29
# Room in hostel                           28
# Entire vacation home                     28
# Private room                             24
# ...

# %%
df_listing2['room_type'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# room_type
# Entire home/apt    11589
# Private room        7615
# Shared room          160
# Hotel room           118
# Name: count, dtype: int64

# %%
df_listing2['amenities'].value_counts(dropna=False) # vemos cuantos valores hay de cada tipo
# Out:
# amenities
# ...

# %%
# VAMOS EN ELIMINAR VARIAS COLUMNA EN EL DF DE LISTING2
df_listing2 = df_listing2.drop(['scrape_id', 'last_scraped', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'calendar_last_scraped'], axis=1)

# %%
df_listing2.shape
df_listing2.head()
# Out:
#       id                         listing_url       source  \
# 0  18674  https://www.airbnb.com/rooms/18674  city scrape
# 1  23197  https://www.airbnb.com/rooms/23197  city scrape
# 2  32711  https://www.airbnb.com/rooms/32711  city scrape
# 3  34241  https://www.airbnb.com/rooms/34241  city scrape
# 4  34981  https://www.airbnb.com/rooms/34981  city scrape
#
#                                                 name  \
# 0    Huge flat for 8 people close to Sagrada Familia
# 1  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                   Sagrada Familia area - Còrsega 1
# 3   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful spacious apartment, large terrace, 5...
# 2  A lovely two bedroom apartment only 250 m from...
# 3  Located in close proximity to Plaza Real and L...
# ...

# %%
# vamos a leer un nuevo archivo de anuncios antes de la nueva ley de AirBnb de Barcelona
df_listing_240615 = pd.read_csv('data/20240615/listings_20240615.csv', low_memory=False)

# %%
df_listing_240615.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  269467  https://www.airbnb.com/rooms/269467  20240615011618   2024-06-15
# 1  270197  https://www.airbnb.com/rooms/270197  20240615011618   2024-06-15
# 2   18674   https://www.airbnb.com/rooms/18674  20240615011618   2024-06-15
# 3  272282  https://www.airbnb.com/rooms/272282  20240615011618   2024-06-15
# 4   23197   https://www.airbnb.com/rooms/23197  20240615011618   2024-06-15
#
#             source                                               name  \
# 0      city scrape       Sunny and quiet Loft next to Sagrada Familia
# 1      city scrape    *monthly stays* 4 Bedroom Apartment near Rambla
# 2      city scrape    Huge flat for 8 people close to Sagrada Familia
# 3  previous scrape             CHARMING, VERY SPACIOUS & BEST LOCATED
# 4      city scrape  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
#
#                                          description  \
# ...

# %%
# vamos a leer un nuevo archivo de anuncios antes de la nueva ley de AirBnb de Barcelona
df_listing_240320 = pd.read_csv('data/20240320/listings_20240320.csv', low_memory=False)

# %%
df_listing_240320
# Out:
#                         id                                       listing_url  \
# 0                   360863               https://www.airbnb.com/rooms/360863
# 1                    17475                https://www.airbnb.com/rooms/17475
# 2                    18674                https://www.airbnb.com/rooms/18674
# 3                    97529                https://www.airbnb.com/rooms/97529
# 4                   110041               https://www.airbnb.com/rooms/110041
# ...                    ...                                               ...
# 18514  1112890415860644617  https://www.airbnb.com/rooms/1112890415860644617
# 18515  1112895488034102784  https://www.airbnb.com/rooms/1112895488034102784
# 18516  1113009460997305948  https://www.airbnb.com/rooms/1113009460997305948
# 18517  1113140418253165522  https://www.airbnb.com/rooms/1113140418253165522
# 18518  1113700263833129118  https://www.airbnb.com/rooms/1113700263833129118
#
# ...

# %%
# vamos a leer un nuevo archivo de anuncios antes de la nueva ley de AirBnb de Barcelona
df_listing_231213 = pd.read_csv('data/20231213/listings_20231213.csv', low_memory=False)

# %%
df_listing_231213
# Out:
#                         id                                       listing_url  \
# 0                    17475                https://www.airbnb.com/rooms/17475
# 1                    18674                https://www.airbnb.com/rooms/18674
# 2                   198958               https://www.airbnb.com/rooms/198958
# 3                   199794               https://www.airbnb.com/rooms/199794
# 4                    23197                https://www.airbnb.com/rooms/23197
# ...                    ...                                               ...
# 18316  1044868355634531312  https://www.airbnb.com/rooms/1044868355634531312
# 18317  1044942014453863903  https://www.airbnb.com/rooms/1044942014453863903
# 18318  1044963280156873186  https://www.airbnb.com/rooms/1044963280156873186
# 18319  1045473737158480598  https://www.airbnb.com/rooms/1045473737158480598
# 18320  1045479945487285016  https://www.airbnb.com/rooms/1045479945487285016
#
# ...

# %%
# Vamos a ver si encontramos los valores faltantes de listing en listing_240615
filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'previous scrape')
faltantes = df_listing2[filtro]

encontrados = faltantes['price'].isin(df_listing_240615['price'])
print(encontrados)
# Out:
# 6        True
# 11       True
# 19       True
# 23       True
# 26       True
#          ...
# 19090    True
# 19130    True
# 19140    True
# 19205    True
# 19206    True
# Name: price, Length: 4050, dtype: bool

# %%
# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_240615 (2024/06/15)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'previous scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_240615[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]
# Out:
#                        id price_prev
# 1                  331026     $41.00
# 2                   71520    $350.00
# 6                  370665    $380.00
# 7                  373667    $253.00
# 12                 504657    $483.00
# ...                   ...        ...
# 3972  1168602475035019681    $115.00
# 3976  1175898115867950587    $235.00
# 3979  1176547265178724610    $117.00
# 3980  1176566088310806158     $58.00
# 3982  1172458373914942965    $110.00
#
# [854 rows x 2 columns]

# %%
# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_240320 (2024/03/20)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'previous scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_240320[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]
# Out:
#                        id price_prev
# 1                  347824    $250.00
# 3                  370665    $260.00
# 8                  504657    $190.00
# 14                 564809     $40.00
# 19                 256982     $50.00
# ...                   ...        ...
# 3491  1105739416698662795     $80.00
# 3494  1106281145511810993     $52.00
# 3495  1106319292472634297     $60.00
# 3503  1115031023374651452     $75.00
# 3504  1115034844833737414    $722.00
#
# [814 rows x 2 columns]

# %%
# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_231213 (2023/12/13)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'previous scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_231213[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]
# Out:
#                        id price_prev
# 1                  360863     $50.00
# 2                  154437     $32.00
# 6                  504657     $90.00
# 12                 564809     $65.00
# 13                 569610    $120.00
# ...                   ...        ...
# 3144  1038422127139783477     $56.00
# 3147  1039713781136345051     $98.00
# 3152  1042555181208811272    $106.00
# 3161  1043962660132365659     $30.00
# 3162  1044179014454001905    $100.00
#
# [1504 rows x 2 columns]

# %%
"""CODIGO CORREGIDO POR DEMETRIOS QUE USÉ, MODIFICANDOLO, EN LA FUNCIONA ANTERIOR Y POSTERIOR"""

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'previous scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_240615[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

df_listing2.loc[filtro, ['id', 'price']]
# Out:
#                         id    price
# 11                  331026      NaN
# 38                  360863  $106.00
# 94                  190348      NaN
# 97                  480975      NaN
# 111                 504657      NaN
# ...                    ...      ...
# 19090  1206490858393976853      NaN
# 19130  1213604516766837218      NaN
# 19140  1207190890830142005      NaN
# 19205  1208467968968860087      NaN
# 19206  1208472359258533658      NaN
#
# [3251 rows x 2 columns]

# %%
# AHORA CORREGIRE EL PRICE USANDO LAS FUNCIONES ANTERIOR TAMBIEN PARA LOS VALORES QUE CONTENGAN CITY_SCRAPE

# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_240615 (2024/06/15)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'city scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_240615[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]

# ---
# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_240320 (2024/03/20)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'city scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_240320[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]

# ---
# Se procede en corregir los valores faltantes de la columna price en el df_listing2 usando los valores de df_listing_231213 (2023/12/13)

filtro = df_listing2['price'].isnull() & (df_listing2['source'] == 'city scrape')
faltantes = df_listing2[filtro]

faltantes_con_precios = faltantes.merge(
    df_listing_231213[['id', 'price']],
    on='id',
    how='left',
    suffixes=('', '_prev')
)

# Filter to only include rows where price_prev is not null
faltantes_con_precios = faltantes_con_precios[faltantes_con_precios['price_prev'].notnull()]

df_listing2.loc[filtro, 'price'] = faltantes_con_precios['price_prev']

faltantes_con_precios[['id', 'price_prev']]
# Out:
#                    id price_prev
# 0              242335     $82.00
# 2            30757362    $109.00
# 3            32302298     $45.00
# 4            46392593     $44.00
# 6  676781565426751262     $72.00
# 7  796840831471490402    $106.00
# 8  832381149589599361    $115.00

# %%
df_listing2.head()
# Out:
#       id                         listing_url       source  \
# 0  18674  https://www.airbnb.com/rooms/18674  city scrape
# 1  23197  https://www.airbnb.com/rooms/23197  city scrape
# 2  32711  https://www.airbnb.com/rooms/32711  city scrape
# 3  34241  https://www.airbnb.com/rooms/34241  city scrape
# 4  34981  https://www.airbnb.com/rooms/34981  city scrape
#
#                                                 name  \
# 0    Huge flat for 8 people close to Sagrada Familia
# 1  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                   Sagrada Familia area - Còrsega 1
# 3   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful spacious apartment, large terrace, 5...
# 2  A lovely two bedroom apartment only 250 m from...
# 3  Located in close proximity to Plaza Real and L...
# ...

# %%
# Vamos a corregir la columna bathrooms donde no hay valores con la columna bathrooms_text utilizando solo la parte numerica
# Extraer la parte numérica de bathrooms_text
df_listing2['bathrooms_extracted'] = df_listing2['bathrooms_text'].str.extract(r'(\d+\.?\d*)').astype(float)

# Rellenar los valores faltantes en bathrooms con bathrooms_extracted
df_listing2['bathrooms'] = df_listing2['bathrooms'].fillna(df_listing2['bathrooms_extracted'])

# Eliminar la columna temporal que ya no es necesaria
df_listing2.drop(columns=['bathrooms_extracted'], inplace=True)

# %%
#Eliminamos de la tabla df_listing2 todos valores que tengan en la columna minimum_nights un valor mayor a 92
df_listing2 = df_listing2[df_listing2['minimum_nights'] <= 92]

# %%
# VAMOS EN ELIMINAR VARIAS COLUMNA EN EL DF DE LISTING2
df_listing2 = df_listing2.drop(['neighborhood_overview', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_has_profile_pic', 'bedrooms',
                                'beds', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes',
                                'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms'], axis=1)

# %%
df_listing2.head()
# Out:
#       id                         listing_url       source  \
# 0  18674  https://www.airbnb.com/rooms/18674  city scrape
# 1  23197  https://www.airbnb.com/rooms/23197  city scrape
# 2  32711  https://www.airbnb.com/rooms/32711  city scrape
# 3  34241  https://www.airbnb.com/rooms/34241  city scrape
# 4  34981  https://www.airbnb.com/rooms/34981  city scrape
#
#                                                 name  \
# 0    Huge flat for 8 people close to Sagrada Familia
# 1  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                   Sagrada Familia area - Còrsega 1
# 3   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful spacious apartment, large terrace, 5...
# 2  A lovely two bedroom apartment only 250 m from...
# 3  Located in close proximity to Plaza Real and L...
# ...

# %%
# Usando el dataframe df_listing2 vamos a crear un mapa interactivos con los barrios de Barcelona usando el fichero neighbourhoods.geojson
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker  
from folium.plugins import HeatMap, MarkerCluster

# %%
# Crear un mapa centrado en Barcelona
m = folium.Map(location=[41.3851, 2.1734], zoom_start=12)

# Agregar marcadores para cada piso
if 'latitude' in df_listing2.columns and 'longitude' in df_listing2.columns:
    for _, row in df_listing2.iterrows():
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Barrio: {row['neighbourhood_cleansed']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

# Guardar el mapa como archivo HTML
m.save("mapa_pisos_barcelona.html")

print("Mapa generado y guardado como 'mapa_pisos_barcelona.html'. Ábrelo en tu navegador para visualizarlo.")
# Out:
# Mapa generado y guardado como 'mapa_pisos_barcelona.html'. Ábrelo en tu navegador para visualizarlo.

# %%
"""# Cargar el archivo geojson
barrios_geojson = gpd.read_file('data/neighbourhoods.geojson')

# Crear un mapa centrado en Barcelona
m = folium.Map(location=[41.3851, 2.1734], zoom_start=13)

# Agregar los barrios al mapa
folium.GeoJson(
    barrios_geojson,
    name='neighbourhoods',
    style_function=lambda feature: {
        'fillColor': '#blue',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5'
    }
).add_to(m)

# Agrupar la información por barrio
barrios_grouped = df_listing2.groupby('neighbourhood_cleansed').agg({
    'latitude': 'mean',
    'longitude': 'mean',
    'id': 'count'
}).reset_index()

# Agregar marcadores para cada barrio
for _, row in barrios_grouped.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Barrio: {row['neighbourhood_cleansed']}, Pisos: {row['id']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Mostramos el mapa interactivo
m
"""
# Out:
# '# Cargar el archivo geojson\nbarrios_geojson = gpd.read_file(\'data/neighbourhoods.geojson\')\n\n# Crear un mapa centrado en Barcelona\nm = folium.Map(location=[41.3851, 2.1734], zoom_start=13)\n\n# Agregar los barrios al mapa\nfolium.GeoJson(\n    barrios_geojson,\n    name=\'neighbourhoods\',\n    style_function=lambda feature: {\n        \'fillColor\': \'#blue\',\n        \'color\': \'black\',\n        \'weight\': 1,\n        \'dashArray\': \'5, 5\'\n    }\n).add_to(m)\n\n# Agrupar la información por barrio\nbarrios_grouped = df_listing2.groupby(\'neighbourhood_cleansed\').agg({\n    \'latitude\': \'mean\',\n    \'longitude\': \'mean\',\n    \'id\': \'count\'\n}).reset_index()\n\n# Agregar marcadores para cada barrio\nfor _, row in barrios_grouped.iterrows():\n    folium.Marker(\n        location=[row[\'latitude\'], row[\'longitude\']],\n        popup=f"Barrio: {row[\'neighbourhood_cleansed\']}, Pisos: {row[\'id\']}",\n        icon=folium.Icon(color=\'blue\', icon=\'info-sign\')\
# ...

# %%
"""
# Crear un mapa centrado en Barcelona
m = folium.Map(location=[41.3851, 2.1734], zoom_start=13)

# Agregar los barrios al mapa
folium.GeoJson(
    barrios_geojson,
    name='neighbourhoods',
    style_function=lambda feature: {
        'fillColor': '#blue',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5'
    }
).add_to(m)

# Agrupar la información por barrio
barrios_grouped = df_listing2.groupby('neighbourhood_cleansed').agg({
    'latitude': 'mean',
    'longitude': 'mean',
    'id': 'count'
}).reset_index()

# Crear una lista de ubicaciones y pesos para el heatmap
heat_data = [[row['latitude'], row['longitude'], row['id']] for index, row in barrios_grouped.iterrows()]

# Agregar el heatmap al mapa
HeatMap(heat_data).add_to(m)

# Mostramos el mapa interactivo
m
"""
# Out:
# "\n# Crear un mapa centrado en Barcelona\nm = folium.Map(location=[41.3851, 2.1734], zoom_start=13)\n\n# Agregar los barrios al mapa\nfolium.GeoJson(\n    barrios_geojson,\n    name='neighbourhoods',\n    style_function=lambda feature: {\n        'fillColor': '#blue',\n        'color': 'black',\n        'weight': 1,\n        'dashArray': '5, 5'\n    }\n).add_to(m)\n\n# Agrupar la información por barrio\nbarrios_grouped = df_listing2.groupby('neighbourhood_cleansed').agg({\n    'latitude': 'mean',\n    'longitude': 'mean',\n    'id': 'count'\n}).reset_index()\n\n# Crear una lista de ubicaciones y pesos para el heatmap\nheat_data = [[row['latitude'], row['longitude'], row['id']] for index, row in barrios_grouped.iterrows()]\n\n# Agregar el heatmap al mapa\nHeatMap(heat_data).add_to(m)\n\n# Mostramos el mapa interactivo\nm\n"

# %%
# Vamos a importar el archivo descargado del ayuntamiento de Bacrelona con los datos de precio media de alquiler por barrio
df_preciomedio = pd.read_csv('data/Precio_Medio_BCN_241009.csv')

# %%
# Cargar el archivo geojson
barrios_geojson = gpd.read_file('data/neighbourhoods.geojson')

# Anadimos una columna price_int en df_listing2 para poder hacer la union con df_preciomedio
df_listing2['price_int'] = df_listing2['price'].str.replace('$', '').str.replace(',', '').astype(float)

# Eliminamos todas lineas que tengan en la columna price_int un valor mayo a 2500
df_listing2 = df_listing2[df_listing2['price_int'] <= 2500]

# Convertimos los valores del df_preciomedio a float para el año 2024
df_preciomedio['2024'] = df_preciomedio['2024'].replace('-', '0').astype(float)

# Agrupar la información por barrio
barrios_grouped = df_listing2.groupby('neighbourhood_cleansed').agg({
    'latitude': 'mean',
    'longitude': 'mean',
    'id': 'count',
    'price_int': 'mean'
}).reset_index()

# Unir los datos de precio medio con barrios_grouped
barrios_grouped = barrios_grouped.merge(df_preciomedio[['Territorio', '2024']], left_on='neighbourhood_cleansed', right_on='Territorio', how='left')

# Crear un mapa centrado en Barcelona
m = folium.Map(location=[41.3851, 2.1734], zoom_start=13)

# Agregar los barrios al mapa
folium.GeoJson(
    barrios_geojson,
    name='neighbourhoods',
    style_function=lambda feature: {
        'fillColor': '#blue',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5'
    }
).add_to(m)

# Agregar marcadores para cada barrio con el precio medio
for _, row in barrios_grouped.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Barrio: {row['neighbourhood_cleansed']}, Pisos: {row['id']}, Precio Medio: {round(float(row['2024']), 2)}, Precio Medio Turistico: {round(row['price_int'], 2)}",
        tooltip=f"Barrio: {row['neighbourhood_cleansed']}, Pisos: {row['id']}, Precio Medio: {round(float(row['2024']), 2)}, Precio Medio Turistico: {round(row['price_int'], 2)}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Mostramos el mapa interactivo
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_listing2.describe().T
# Out:
#                                count          mean           std  \
# id                           16197.0  4.864751e+17  4.994833e+17
# host_id                      16197.0  1.863420e+08  1.958707e+08
# host_listings_count          16195.0  5.774937e+01  1.337143e+02
# host_total_listings_count    16195.0  7.336863e+01  1.552683e+02
# latitude                     16197.0  4.139220e+01  1.397569e-02
# longitude                    16197.0  2.166965e+00  1.753406e-02
# accommodates                 16197.0  3.474471e+00  2.171242e+00
# bathrooms                    16182.0  1.390712e+00  7.155332e-01
# minimum_nights               16197.0  1.381299e+01  1.555354e+01
# maximum_nights               16197.0  5.292134e+02  4.088549e+02
# availability_30              16197.0  8.075014e+00  9.169172e+00
# availability_60              16197.0  2.208508e+01  1.924380e+01
# availability_90              16197.0  4.186683e+01  2.866142e+01
# ...

# %%
# guardamos el dataframe df_lisnting2 en un nuevo archivo csv
df_listing2.to_csv('data/listings2_editado.csv', index=False)

# %%
df_listing2.head()
# Out:
#       id                         listing_url       source  \
# 0  18674  https://www.airbnb.com/rooms/18674  city scrape
# 1  23197  https://www.airbnb.com/rooms/23197  city scrape
# 2  32711  https://www.airbnb.com/rooms/32711  city scrape
# 3  34241  https://www.airbnb.com/rooms/34241  city scrape
# 4  34981  https://www.airbnb.com/rooms/34981  city scrape
#
#                                                 name  \
# 0    Huge flat for 8 people close to Sagrada Familia
# 1  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                   Sagrada Familia area - Còrsega 1
# 3   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful spacious apartment, large terrace, 5...
# 2  A lovely two bedroom apartment only 250 m from...
# 3  Located in close proximity to Plaza Real and L...
# ...

# %%
# Leemos el archivo csv Precio_Medio_BCN_241009.csv
df_preciomedio = pd.read_csv('data/Precio_Medio_BCN_241009.csv')

# %%
df_preciomedio.head()
# Out:
#                  Territorio           Tipo de territorio         2000  \
# 0                 Catalunya           Comunitat Autònoma            -
# 1  Metropolità de Barcelona  Àmbit funcional territorial            -
# 2                 Barcelona                     Municipi  408.2685322
# 3              Ciutat Vella                    Districte   325.191895
# 4                  el Raval                        Barri            -
#
#           2001         2002         2003         2004         2005  \
# 0            -            -            -            -  552.0147952
# 1            -            -            -            -  596.0024329
# 2  466.3374181  519.8091215  550.5919991  584.7805514  636.0211689
# 3  350.9249161  412.0531833  443.1504516  469.8563702  539.2881261
# 4            -            -            -            -            -
#
#           2006         2007         2008         2009         2010  \
# 0  602.7587591  645.3627677  677.9943908  650.3302911    614.54642
# ...

# %%
import matplotlib.pyplot as plt

# Filtrar los datos para incluir solo el tipo de territorio "Municipi"
df_municipi = df_preciomedio[df_preciomedio['Tipo de territorio'] == 'Municipi']

# Seleccionar las columnas de años y convertirlas a números
df_municipi_evol = df_municipi.melt(id_vars=['Territorio'], var_name='Año', value_name='Precio', ignore_index=False)
df_municipi_evol = df_municipi_evol[df_municipi_evol['Año'].str.isdigit()]  # Filtrar solo columnas de años
df_municipi_evol['Año'] = pd.to_numeric(df_municipi_evol['Año'], errors='coerce')
df_municipi_evol['Precio'] = pd.to_numeric(df_municipi_evol['Precio'], errors='coerce')

# Eliminar valores nulos
df_municipi_evol = df_municipi_evol.dropna()

# Filtrar los últimos 10 años
ultimo_ano = df_municipi_evol['Año'].max()
df_municipi_evol = df_municipi_evol[df_municipi_evol['Año'] >= (ultimo_ano - 10)]

# Crear el gráfico
plt.figure(figsize=(10, 6))
for municipio in df_municipi_evol['Territorio'].unique():
    data = df_municipi_evol[df_municipi_evol['Territorio'] == municipio]
    plt.plot(data['Año'], data['Precio'], label=municipio)

# Configurar el gráfico
plt.title('Evolución del Precio por Año (Últimos 10 Años, Tipo de Territorio: Municipi)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Precio Medio', fontsize=12)
plt.legend(title='Territorio', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# quiero comparar en un grafico la columna license de los dataframe df_listing2, df_listing_240615, df_listing_240320 y df_listing_231213

import seaborn as sns

# Creamos un diccionario para iterar fácilmente por los dataframes
dataframes = {
    'Sep-24': df_listing2,
    'Jun-24': df_listing_240615,
    'Mar-24': df_listing_240320,
    'Dec-23': df_listing_231213
}
# En esta lista almacenaremos las estadísticas de cada dataframe
registros = []

for nombre, df in dataframes.items():
    # Conteo de valores "Exempte"
    exempte_count = df['license'].eq('Exempt').sum()

    # Conteo de valores faltantes
    missing_count = df['license'].isna().sum()

    # Valores diferentes (excluyendo NA y "Exempte")
    valores_unicos = df['license'].dropna().unique().tolist()
    if 'Exempte' in valores_unicos:
        valores_unicos.remove('Exempt')
    different_count = len(valores_unicos)

    registros.append([nombre, different_count, missing_count, exempte_count])

# Creamos un DataFrame con las estadísticas
df_plot = pd.DataFrame(registros, columns=['DataFrame', 'Valores Diferentes', 'Valores Faltantes', 'Valor Exempt'])

# Reestructuramos el DataFrame para facilitar el plot con seaborn
df_plot_melted = df_plot.melt(id_vars='DataFrame',
                              value_vars=['Valores Diferentes', 'Valores Faltantes', 'Valor Exempt'],
                              var_name='Categoria', value_name='Conteo')

# Graficamos
plt.figure(figsize=(15,6))
sns.barplot(x='DataFrame', y='Conteo', hue='Categoria', data=df_plot_melted)
plt.title('Comparación de valores en la columna "license"')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# del dataframe df_listing_240615 quiero conservar solo las columnas is, property_type, room_type y license
df_listing_240320_2 = df_listing_240320[['id', 'property_type', 'room_type', 'license', 'neighbourhood_group_cleansed']]
df_listing_231213_2 = df_listing_231213[['id', 'property_type', 'room_type', 'license', 'neighbourhood_group_cleansed']]
df_listing_240615_2 = df_listing_240615[['id', 'property_type', 'room_type', 'license', 'neighbourhood_group_cleansed']]
df_listing2_2 = df_listing2[['id', 'property_type', 'room_type', 'license', 'neighbourhood_group_cleansed']]

# salvamos los nuevos csv
df_listing_240320_2.to_csv('data/listings_20240320_editado.csv', index=False)
df_listing_231213_2.to_csv('data/listings_20231213_editado.csv', index=False)
df_listing_240615_2.to_csv('data/listings_20240615_editado.csv', index=False)
df_listing2_2.to_csv('data/listings2_2_editado.csv', index=False)
